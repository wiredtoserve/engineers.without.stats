# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import os
import json

# %%
data_dir = '/Users/mehulnagpurkar/Documents/GitHub/engineers.without.stats/Case Study/dataFiles/yelp_dataset/'
profiles_path = os.path.join(data_dir, 'business.json')

# %%
profiles_path
# Out:
# '/Users/mehulnagpurkar/Documents/GitHub/engineers.without.stats/Case Study/dataFiles/yelp_dataset/business.json'

# %%
#df = pd.read_json('business.json', lines = True)

# %%
df = pd.read_json(profiles_path, lines = True)

# %%
df.head()
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                           address         city state postal_code   latitude  \
# 0     2818 E Camino Acequia Drive      Phoenix    AZ       85016  33.522143
# 1            30 Eglinton Avenue W  Mississauga    ON     L5R 3E7  43.605499
# 2       10110 Johnston Rd, Ste 15    Charlotte    NC       28210  35.092564
# 3   15655 W Roosevelt St, Ste 237     Goodyear    AZ       85338  33.455613
# 4  4209 Stuart Andrew Blvd, Ste F    Charlotte    NC       28217  35.190012
#
#     longitude  stars  review_count  is_open  \
# 0 -112.018481    3.0             5        0
# 1  -79.652289    2.5           128        1
# ...

# %%
df['attributes'].apply(lambda x:x.keys() if x else '')
# Out:
# 0                                             (GoodForKids)
# 1         (RestaurantsReservations, GoodForMeal, Busines...
# 2         (GoodForKids, NoiseLevel, RestaurantsDelivery,...
# 3
# 4         (BusinessAcceptsBitcoin, ByAppointmentOnly, Bu...
#                                 ...
# 192604                         (BusinessAcceptsCreditCards)
# 192605    (RestaurantsPriceRange2, BikeParking, Business...
# 192606      (BusinessAcceptsCreditCards, ByAppointmentOnly)
# 192607    (RestaurantsPriceRange2, BusinessAcceptsCredit...
# 192608                (BikeParking, RestaurantsPriceRange2)
# Name: attributes, Length: 192609, dtype: object

# %%
df['name'].value_counts().index.tolist()
# Out:
# ['Starbucks',
#  "McDonald's",
#  'Subway',
#  'Tim Hortons',
#  'Pizza Hut',
#  'Taco Bell',
#  'Burger King',
#  'Walgreens',
#  "Wendy's",
#  'The UPS Store',
#  'CVS Pharmacy',
#  'Great Clips',
#  'Circle K',
#  'Enterprise Rent-A-Car',
#  "Domino's Pizza",
#  'KFC',
#  "Dunkin' Donuts",
#  'Chase Bank',
#  'Chipotle Mexican Grill',
#  'Wells Fargo Bank',
#  '7-Eleven',
#  'Dairy Queen',
#  'Bank of America',
#  'Panera Bread',
#  "Jimmy John's",
#  'Panda Express',
#  "Papa John's Pizza",
#  'Popeyes Louisiana Kitchen',
#  'Supercuts',
#  'T-Mobile',
#  "Arby's",
#  'US Post Office',
#  'Shoppers Drug Mart',
#  'The Home Depot',
#  "Denny's",
#  'QuikTrip',
#  'Target',
#  'Little Caesars Pizza',
#  'Firestone Complete Auto Care',
#  'Jiffy Lube',
#  'Anytime Fitness',
#  'Walmart Supercenter',
#  'PetSmart',
#  'Dollar Tree',
#  'Pizza Pizza',
#  'Second Cup',
#  'AT&T Store',
#  'Five Guys',
#  'Public Storage',
#  'Giant Eagle',
#  "Jersey Mike's Subs",
# ...

# %%
df[df['name'] == "McDonald's"].head()
# Out:
#                  business_id        name             address             city  \
# 1278  PF5rHGGZ93i7UJP9Fsvgmg  McDonald's  8452 W Thunderbird           Peoria
# 1529  8RbNzNeaUh5e8PJOnp1e4Q  McDonald's      1029 N Main St           Oregon
# 1798  Sr_VUJBhqcKCDLRv0JkrDg  McDonald's      1650 Copley Rd            Akron
# 2298  bHGxQS3wfX93sMFOuR6xDw  McDonald's       3229 Losee Rd  North Las Vegas
# 2610  LgRiEJPaocDHyRLLOh9iMQ  McDonald's         9710 Rea Rd        Charlotte
#
#      state postal_code   latitude   longitude  stars  review_count  is_open  \
# 1278    AZ       85381  33.610429 -112.240870    2.0            32        1
# 1529    WI       53575  42.942315  -89.383746    1.0            13        1
# 1798    OH       44320  41.084159  -81.581385    1.0             3        1
# 2298    NV       89030  36.219109 -115.126973    1.5            14        0
# 2610    NC       28277  35.037217  -80.805520    1.5            47        1
#
# ...

# %%
df.groupby('name').describe()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-ccaa5c2b1a9f> in <module>
# ----> 1 df.groupby('name').describe()
#
# ~/anaconda3/envs/analytics/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in describe(self, **kwargs)
#    1443     def describe(self, **kwargs):
#    1444         with _group_selection_context(self):
# -> 1445             result = self.apply(lambda x: x.describe(**kwargs))
#    1446             if self.axis == 1:
#    1447                 return result.T
#
# ~/anaconda3/envs/analytics/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#     723         with option_context("mode.chained_assignment", None):
#     724             try:
# --> 725                 result = self._python_apply_general(f)
#     726             except Exception:
#     727
#
# ...

# %%
df['name'].value_counts()
# Out:
# Starbucks                      1066
# McDonald's                      806
# Subway                          768
# Tim Hortons                     333
# Pizza Hut                       320
#                                ...
# The Tavern At Loyal Oak           1
# The Resort On Mt Charleston       1
# El Sabroso Hot Dog                1
# Bootmaker                         1
# Jimmy and Joe's Pizzeria          1
# Name: name, Length: 145046, dtype: int64

# %%
df['state'].value_counts()
# Out:
# AZ     56686
# NV     36312
# ON     33412
# NC     14720
# OH     14697
# PA     11216
# QC      9219
# AB      8012
# WI      5154
# IL      1932
# SC      1162
# NY        22
# CA        19
# TX         6
# FL         4
# XGM        4
# CT         3
# AL         3
# WA         3
# NE         2
# VT         2
# GA         2
# XWY        2
# AK         2
# VA         2
# BC         1
# TN         1
# BAS        1
# NM         1
# UT         1
# DOW        1
# DUR        1
# NJ         1
# AR         1
# CON        1
# XGL        1
# Name: state, dtype: int64

# %%
df[df['state'] == 'AZ'].mean()
# Out:
# latitude         33.492683
# longitude      -111.993683
# stars             3.707185
# review_count     35.337561
# is_open           0.827541
# dtype: float64
