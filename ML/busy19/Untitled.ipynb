# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#from igraph import *
from math import *
import sys
import os
import glob
import random
from random import shuffle
from random import seed
import time
import datetime
import collections

# %%
graph = {}
with open('train.txt') as inp:
    for l in inp.readlines():
        graph[l.strip().split("\t")[0]] = l.strip().split("\t")[1:]
        #print(l.strip().split("\t")[0])
    #test =  list(zip(*(line.strip().split('\t') for line in inp)))

# %%
new_dict = {}

for key in graph.keys():
    new_dict[key] = len(graph[key])

# %%
len(graph)
# Out:
# 20000

# %%
xx = sorted([(val, key) for key, val in new_dict.items()], reverse=True)

# %%
yy = sorted([val for key, val in new_dict.items()], reverse=True)

# %%
plt.hist(yy)
# Out:
# (array([1.9965e+04, 2.8000e+01, 1.0000e+00, 1.0000e+00, 0.0000e+00,
#         3.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([     0. ,  76419.5, 152839. , 229258.5, 305678. , 382097.5,
#         458517. , 534936.5, 611356. , 687775.5, 764195. ]),
#  <a list of 10 Patch objects>)

# %%
[[x] for x in graph['1812114']]
# Out:
# [['2220067'],
#  ['1643268'],
#  ['4420406'],
#  ['768770'],
#  ['2984603'],
#  ['1151104'],
#  ['2949748'],
#  ['3964030'],
#  ['1401429'],
#  ['4445347'],
#  ['3474637'],
#  ['202912'],
#  ['2665155'],
#  ['4515906'],
#  ['4203761'],
#  ['3503714'],
#  ['4011346'],
#  ['3372240'],
#  ['4830900'],
#  ['4478715'],
#  ['1800325'],
#  ['2427345'],
#  ['4473002'],
#  ['321961'],
#  ['395745'],
#  ['1058463'],
#  ['1689039'],
#  ['1866148'],
#  ['4527149'],
#  ['537589'],
#  ['3681341'],
#  ['2934550'],
#  ['2253687'],
#  ['2842633'],
#  ['2706750'],
#  ['3959708'],
#  ['40581'],
#  ['1782614'],
#  ['962665'],
#  ['154041'],
#  ['274950'],
#  ['1863500'],
#  ['4299022'],
#  ['4662311'],
#  ['1631312'],
#  ['1662115'],
#  ['3658184'],
#  ['16658'],
#  ['1028454'],
#  ['3007223'],
#  ['4751012'],
#  ['2644807'],
#  ['3039868'],
#  ['1817336'],
#  ['2428686'],
#  ['3975929'],
#  ['1209120'],
#  ['2966560'],
#  ['1233075'],
#  ['3698761'],
#  ['3284140'],
#  ['3839632'],
#  ['1523392'],
# ...

# %%
len(graph)
# Out:
# 20000

# %%
nodes = set()
for l in graph.values():
    for n in l:
        nodes.add(n)

# %%
len(nodes)
# Out:
# 4867136

# %%
X = np.array([])
y = np.array([])

# %%
X_list = []
y_list = []

# %%
for key, val in graph.items():
    #X = np.array(val)
    X_list.append(val)
    y_list.append(key)

# %%
X = np.array(X_list)

# %%
y = np.array(y_list)

# %%
arr = []
arr.append([1,2,3])
arr.append([4,5,6])
np_arr = np.array(arr)

# %%
len(y)
# Out:
# 20000

# %%
X.shape
# Out:
# (20000,)

# %%
t = np.reshape(X, (-1, ncols))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-22a67ff26bde> in <module>()
# ----> 1 t = np.reshape(X, (-1, ncols))
#
# NameError: name 'ncols' is not defined

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-4da22249824e> in <module>()
# ----> 1 rfc.fit(X,y)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py in fit(self, X, y, sample_weight)
#     245         """
#     246         # Validate or convert input data
# --> 247         X = check_array(X, accept_sparse="csc", dtype=DTYPE)
#     248         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#     249         if sample_weight is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# ...
